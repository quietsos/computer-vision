# %% [markdown]
# <!-- There have three color coading:
#         1. RGB (Red, green, blue coor combination coading)
#         2. HSL (hue,saturation,lightness)
#         3. HSV(hue, saturation, value)
#          -->

# %%
# There are three coloar coading:
#     1. RGB (Red, green, blue)
#     2. HLS (hue, satuaration, lightness)
#     3. HSV (hue, satuaration, value)

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../data/sohan.jpg')

# %%
img
# Out:
# array([[[166, 156, 162],
#         [171, 161, 167],
#         [176, 166, 172],
#         ...,
#         [170, 181, 189],
#         [166, 177, 185],
#         [163, 174, 182]],
#
#        [[167, 157, 163],
#         [171, 161, 167],
#         [177, 167, 173],
#         ...,
#         [169, 182, 190],
#         [167, 178, 186],
#         [163, 176, 184]],
#
#        [[167, 158, 161],
#         [171, 162, 165],
#         [177, 168, 171],
#         ...,
#         [169, 185, 192],
#         [167, 180, 188],
#         [163, 179, 186]],
#
#        ...,
#
#        [[232, 244, 250],
#         [232, 244, 250],
#         [232, 244, 250],
#         ...,
#         [226, 242, 248],
#         [226, 242, 248],
#         [226, 242, 248]],
#
#        [[232, 244, 250],
#         [232, 244, 250],
#         [232, 244, 250],
#         ...,
#         [224, 243, 248],
#         [224, 243, 248],
#         [224, 243, 248]],
#
#        [[232, 244, 250],
#         [232, 244, 250],
#         [232, 244, 250],
# ...

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_HSV2RGB)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_RGB2HLS)

# %%
plt.imshow(img)
