# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('data/sohan.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=864x771 at 0x7F985FC42590>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
picArray = np.asarray(pic)

# %%
picArray
# Out:
# array([[[162, 156, 166],
#         [167, 161, 171],
#         [172, 166, 176],
#         ...,
#         [189, 181, 170],
#         [185, 177, 166],
#         [182, 174, 163]],
#
#        [[163, 157, 167],
#         [167, 161, 171],
#         [173, 167, 177],
#         ...,
#         [190, 182, 169],
#         [186, 178, 167],
#         [184, 176, 165]],
#
#        [[163, 157, 167],
#         [167, 161, 171],
#         [173, 167, 177],
#         ...,
#         [192, 184, 171],
#         [188, 180, 167],
#         [186, 178, 165]],
#
#        ...,
#
#        [[250, 244, 232],
#         [250, 244, 232],
#         [250, 244, 232],
#         ...,
#         [248, 243, 224],
#         [248, 243, 224],
#         [248, 243, 224]],
#
#        [[250, 244, 232],
#         [250, 244, 232],
#         [250, 244, 232],
#         ...,
#         [248, 243, 224],
#         [248, 243, 224],
#         [248, 243, 224]],
#
#        [[250, 244, 232],
#         [250, 244, 232],
#         [250, 244, 232],
#         ...,
#         [248, 243, 224],
#         [248, 243, 224],
#         [248, 243, 224]]], dtype=uint8)

# %%
type(picArray)
# Out:
# numpy.ndarray

# %%
picArray.shape
# Out:
# (771, 864, 3)

# %%
plt.imshow(picArray)

# %%
pic_red = picArray.copy()
pic_green = picArray.copy()
pic_blue = picArray.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (771, 864, 3)

# %%
# R G B/
red = pic_red[:,:,1]
plt.imshow(pic_red[:,:,1])
plt.imshow(red)

# %%
red
# Out:
# array([[156, 161, 166, ..., 181, 177, 174],
#        [157, 161, 167, ..., 182, 178, 176],
#        [157, 161, 167, ..., 184, 180, 178],
#        ...,
#        [244, 244, 244, ..., 243, 243, 243],
#        [244, 244, 244, ..., 243, 243, 243],
#        [244, 244, 244, ..., 243, 243, 243]], dtype=uint8)

# %%
plt.imshow(pic_green)

# %%
green = pic_green[:,:,2]

# %%
plt.imshow(green)

# %%
blue = pic_blue[:,:,0]

# %%
plt.imshow(blue,cmap='gray')

# %%
#  red channel
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
# green chanel
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
#  blue channel
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
#  red channel
plt.imshow(pic_red[:,:,0])

# %%
# green chanel
plt.imshow(pic_red[:,:,1])

# %%
#  blue channel
plt.imshow(pic_red[:,:,2])

# %%
#RED channel 
pic_red[:,:,1]=0

# %%
pic_red[:,:,2]=0

# %%
plt.imshow(pic_red)

# %%
#GREEN channel
plt.imshow(pic_green)

# %%
pic_green[:,:,0] =0

# %%
pic_green[:,:,2]=0

# %%
plt.imshow(pic_green)

# %%
#BLUE channel
plt.imshow(pic_blue)

# %%
pic_blue[:,:,0]=0

# %%
pic_blue[:,:,1]=0

# %%
plt.imshow(pic_blue)

# %%
pic_blue.shape
# Out:
# (771, 864, 3)

# %%
pic_blue[:,:,0].shape
# Out:
# (771, 864)
